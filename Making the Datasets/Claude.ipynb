# %%
import pandas as pd

# %%
df = pd.read_csv('Datasets/h+a+i.csv')

# %%
df.head()
# Out:
#                                            Headlines  \
# 0  Coal India revises e-auction norms: Is there m...
# 1    D-Mart: Margin miss in Q1; valuations expensive
# 2  TCS chief cautious of economic slowdown, but r...
# 3  SBI raises lending rates by 5-10 bps across mo...
# 4  Investors of TCS, HCL should tally their optim...
#
#                                              Article  Interest
# 0  Highlights  Coal India announces plans to ease...         1
# 1  Highlights  Healthy revenue growth, but margin...         1
# 2  Tata Consultancy Services Ltd (TCS) stays caut...         1
# 3  State Bank of India (SBI) has raised its bench...         1
# 4  Shares of Tata Consultancy Services (TCS) and ...         0

# %%
headlines = list(df['Headlines'])

# %%
df.shape, len(headlines)
# Out:
# ((249, 3), 249)

# %%
import anthropic
import time
from tenacity import retry, wait_exponential, stop_after_attempt

client = anthropic.Anthropic(api_key=#Put your key here) 

# Retry decorator
@retry(wait=wait_exponential(multiplier=1, min=4, max=10), stop=stop_after_attempt(5))
def make_api_call(headline):
    return client.messages.create(
        model="claude-3-5-sonnet-20240620",
        max_tokens=1000,
        temperature=0,
        system="You are an expert in identifying companies and their sectors from news headlines. Respond with the company name followed by a comma and then the sector.If you are unable to find a company, just put None in both company and sector.Also if there are more than one company, just answer with the first one",
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "text",
                        "text": f"Identify the company and its sector from this headline: {headline}"
                    }
                ]
            }
        ]
    )

# List of headlines

# Lists to store companies and sectors
companies = []
sectors = []

# Loop through each headline
for headline in headlines:
    try:
        message = make_api_call(headline)
        
        # Extract the text content from the message
        response = message.content[0].text if isinstance(message.content, list) else message.content.text
        
        # Now we can safely use strip() and split()
        response = response.strip()
        company, sector = response.split(',')
        
        # Append to the respective lists
        companies.append(company.strip())
        sectors.append(sector.strip())
        
        # Print the result
        print(f"Headline: {headline}")
        print(f"Company: {company.strip()}")
        print(f"Sector: {sector.strip()}")
        print("-" * 50)
        
        # Add a delay between requests
        time.sleep(1)
    except Exception as e:
        print(f"Error processing headline: {headline}")
        print(f"Error: {str(e)}")
# Out:
# Headline: Coal India revises e-auction norms: Is there more upside to the stock now?
# Company: Coal India
# Sector: Energy
# --------------------------------------------------
# Headline: D-Mart: Margin miss in Q1; valuations expensive
# Company: D-Mart
# Sector: Retail
# --------------------------------------------------
# Headline: TCS chief cautious of economic slowdown, but remains confident of future growth
# Company: TCS
# Sector: Information Technology
# --------------------------------------------------
# Headline: SBI raises lending rates by 5-10 bps across most tenures
# Company: SBI
# Sector: Banking
# --------------------------------------------------
# Headline: Investors of TCS, HCL should tally their optimism with ISG index
# Company: TCS
# Sector: Information Technology
# --------------------------------------------------
# Headline: Morning Scan: All the big stories to get you started for the day
# Company: None
# Sector: None
# --------------------------------------------------
# Headline: Adani plans to build port in Vietnam to tap trade opportunities
# Company: Adani
# Sector: Infrastructure
# --------------------------------------------------
# Headline: Cyril Amarchand's Shishir Vayttaden to join Khaitan & Co along with 2 other partners
# Company: Khaitan & Co
# Sector: Legal Services
# --------------------------------------------------
# Headline: Business in the Week Ahead: July 15-19
# Company: None
# Sector: None
# --------------------------------------------------
# Headline: Tata Power invests over Rs 4,200 crore in network expansion, upgrade in Odisha
# Company: Tata Power
# Sector: Utilities
# --------------------------------------------------
# Headline: Domestic PV wholesales up 3% at 3,37,757 units in June: SIAM
# Company: None
# Sector: None
# --------------------------------------------------
# Headline: What can the Union Budget do to address the woes of Indian agriculture?
# Company: None
# Sector: None
# --------------------------------------------------
# Headline: Weekly Tactical Pick: Why this affordable housing play deserves attention
# Company: LIC Housing Finance
# Sector: Financial Services
# --------------------------------------------------
# Headline: Boeing warns customers of further delays on 737 Max
# Company: Boeing
# Sector: Aerospace & Defense
# --------------------------------------------------
# Headline: Oil rises on cooling US inflation, strong summer demand
# Company: None
# Sector: None
# --------------------------------------------------
# Headline: Adani Ports to invest $1.2 billion in transshipment terminal
# Company: Adani Ports
# Sector: Industrials
# --------------------------------------------------
# Headline: Tesla delays Robotaxi rollout in blow to Elon Musk’s autonomy drive
# Company: Tesla
# Sector: Automotive
# --------------------------------------------------
# Headline: Bain Capital to buy financial software vendor Envestnet in $4.5 billion deal
# Company: Envestnet
# Sector: Financial Services
# --------------------------------------------------
# Headline: Govt appoints Sandeep Kumar as Director (Finance) at PFC
# Company: Power Finance Corporation (PFC)
# Sector: Utilities
# --------------------------------------------------
# Headline: Hindustan Zinc gets power supply from Serentica 180 MW solar project
# Company: Hindustan Zinc
# Sector: Mining
# --------------------------------------------------
# Headline: PepsiCo quarterly revenue misses on slowing demand for snacks, sodas
# Company: PepsiCo
# Sector: Consumer Staples
# --------------------------------------------------
# Headline: Pfizer moves forward with once-daily weight loss pill
# Company: Pfizer
# Sector: Healthcare
# --------------------------------------------------
# Headline: Vedanta to raise up to Rs 1,000 crore via debentures
# Company: Vedanta
# Sector: Mining and Metals
# --------------------------------------------------
# Headline: ONGC higher on hopes of getting US waiver to lift Venezuelan oil
# Company: ONGC
# Sector: Energy
# --------------------------------------------------
# Headline: Electric mobility startup Vidyut launches offline pre-owned EV sales, financing platform
# Company: Vidyut
# Sector: Electric Vehicles/Automotive
# --------------------------------------------------
# Headline: SCI, NMDC Steel shares rally up to 19% amid buzz of likely strategic sale
# Company: SCI
# Sector: Transportation
# --------------------------------------------------
# Headline: First Abu Dhabi Bank says not evaluating any offer for stake in Yes Bank
# Company: First Abu Dhabi Bank
# Sector: Banking
# --------------------------------------------------
# Headline: This is the best stock to play robust inflows into mutual funds
# Company: None
# Sector: None
# --------------------------------------------------
# Headline: Kalpataru Projects International bags orders worth Rs 2,995 crore
# Company: Kalpataru Projects International
# Sector: Construction & Engineering
# --------------------------------------------------
# Headline: KNR Constructions: New order wins to drive re-rating
# Company: KNR Constructions
# Sector: Construction
# --------------------------------------------------
# Headline: KIMS should see results from Vizag hospital acquisition early
# Company: KIMS
# Sector: Healthcare
# --------------------------------------------------
# Headline: Accenture acquires Cientra in a bid to expand silicon design capabilities
# Company: Accenture
# Sector: Technology Consulting and Services
# --------------------------------------------------
# Headline: Aavas Financiers: EQT, CVC Capital & Bain in the fray as promoters Kedaara, Partners Group explore full exit
# Company: Aavas Financiers
# Sector: Financial Services
# --------------------------------------------------
# Headline: Sula Vineyards' net revenue jumps 10% to Rs 130 cr in Q1FY25, its highest ever
# Company: Sula Vineyards
# Sector: Consumer Goods (Beverages/Wine)
# --------------------------------------------------
# Headline: Signature Global to invest Rs 2,500 crore on construction of current housing projects in FY25: CMD
# Company: Signature Global
# Sector: Real Estate
# --------------------------------------------------
# Headline: No link between UP hybrid car policy and XUV 700 price cut, clarifies M&M
# Company: Mahindra & Mahindra (M&M)
# Sector: Automotive
# --------------------------------------------------
# Headline: Tata Motors, Mahindra cut SUV prices to boost demand
# Company: Tata Motors
# Sector: Automotive
# --------------------------------------------------
# Headline: SC stays Gujarat HC's order directing recovery of 108-hectare land from Adani Ports
# Company: Adani Ports
# Sector: Transportation
# --------------------------------------------------
# Headline: Juniper Green inks pacts to supply 480 MW from solar-wind hybrid projects
# Company: Juniper Green
# Sector: Renewable Energy
# --------------------------------------------------
# Headline: GE Power India gets order to supply main turbine spares
# Company: GE Power India
# Sector: Industrial Goods
# --------------------------------------------------
# Headline: JLR India retail sales rise 31% at 1,371 units in Q1
# Company: Jaguar Land Rover
# Sector: Automotive
# --------------------------------------------------
# Headline: JSW MG Motor joins hands with Shell for EV charging infra
# Company: JSW MG Motor
# Sector: Automotive
# --------------------------------------------------
# Headline: Tata Trusts forms executive committee to speed up decision making: Report
# Company: Tata Trusts
# Sector: Conglomerate
# --------------------------------------------------
# Headline: Karur Vysya Bank — Is the current stock weakness an opportunity?
# Company: Karur Vysya Bank
# Sector: Financial Services
# --------------------------------------------------
# Headline: Gold rangebound with spotlight on US inflation reading
# Company: None
# Sector: None
# --------------------------------------------------
# Headline: Hyundai's CSR wing to support 20 para-athletes for 3 years
# Company: Hyundai
# Sector: Automotive
# --------------------------------------------------
# Headline: Infosys partners with Sector Alarm to fuel growth via cloud-based solutions
# Company: Infosys
# Sector: Information Technology Services
# --------------------------------------------------
# Headline: Phenomenal launches full text-to-video AI platform
# Company: None
# Sector: None
# --------------------------------------------------
# Headline: Alembic Pharma gets USFDA nod for generic Bromfenac ophthalmic solution
# Company: Alembic Pharma
# Sector: Healthcare/Pharmaceuticals
# --------------------------------------------------
# Headline: Ashwin Sheth Group to invest Rs 5,000 crore to expand real estate business; to launch IPO in 2 years
# Company: Ashwin Sheth Group
# Sector: Real Estate
# --------------------------------------------------
# Headline: Hyundai under pressure from Tata, Mahindra as $3.5 billion India IPO looms
# Company: Hyundai
# Sector: Automotive
# --------------------------------------------------
# Headline: RateGain stock jumps 5% on multi-year deal with Malaysia Airlines
# Company: RateGain
# Sector: Technology
# --------------------------------------------------
# Error processing headline: Why this leading auto component maker stays in the spotlight
# Error: too many values to unpack (expected 2)
# Headline: Inox Wind bags order for 200 MW wind project in Gujarat, Rajasthan
# Company: Inox Wind
# Sector: Energy
# --------------------------------------------------
# Headline: RKN Enterprises sells 12.65% stake in Godrej Industries for Rs 3,803 crore under settlement plan
# Company: Godrej Industries
# Sector: Consumer Goods
# --------------------------------------------------
# Headline: Mahanagar Gas hikes rates for CNG and domestic PNG in Mumbai
# Company: Mahanagar Gas
# Sector: Utilities
# --------------------------------------------------
# Headline: Delta Corp shares jump 8% a day ahead of Q1FY25 earnings
# Company: Delta Corp
# Sector: Gaming
# --------------------------------------------------
# Headline: Bharat Petroleum among eight bidders for Sri Lankan LPG company and terminal
# Company: Bharat Petroleum
# Sector: Energy
# --------------------------------------------------
# Headline: Southwest Air names aviation industry veteran Rakesh Gangwal to board
# Company: Southwest Airlines
# Sector: Transportation
# --------------------------------------------------
# Headline: Tata a step closer to merging four group airlines into two by harmonising operating manuals
# Company: Tata Group
# Sector: Aviation
# --------------------------------------------------
# Headline: Mercedes-Benz India posts record half-yearly sales at 9,262 units
# Company: Mercedes-Benz
# Sector: Automotive
# --------------------------------------------------
# Headline: MAN Industries gets Rs 1,850 crore order from international firm for LNG project
# Company: MAN Industries
# Sector: Industrial Manufacturing
# --------------------------------------------------
# Headline: Maruti Suzuki plans to dispatch 35% of total vehicle production via railways in 7-8 years
# Company: Maruti Suzuki
# Sector: Automotive
# --------------------------------------------------
# Headline: Welspun One raises Rs 2,275 crore for second fund to build warehousing assets
# Company: Welspun One
# Sector: Real Estate
# --------------------------------------------------
# Headline: L&T wins mega orders to build 3.5 GW solar PV plants in Middle East
# Company: L&T
# Sector: Industrial Conglomerates
# --------------------------------------------------
# Headline: Capital Small Finance Bank – Why the time is right to look at this stock
# Company: Capital Small Finance Bank
# Sector: Banking
# --------------------------------------------------
# Headline: Titan Company: Q1 misses estimates; long-term story intact
# Company: Titan Company
# Sector: Consumer Discretionary
# --------------------------------------------------
# Headline: Adani Green plans $9 billion infrastructure spend on green hydrogen in Phase one: Report
# Company: Adani Green Energy
# Sector: Energy
# --------------------------------------------------
# Headline: Gig Workers and Large Companies: A symbiotic relationship under threat
# Company: None
# Sector: None
# --------------------------------------------------
# Headline: Tata Chemicals’ fortunes tied to soda ash amid slow ramp-up of specialty business
# Company: Tata Chemicals
# Sector: Chemicals
# --------------------------------------------------
# Headline: Morning Scan: Essential stories to kickstart your day
# Company: None
# Sector: None
# --------------------------------------------------
# Headline: Signature Global reports strong Q1 FY25 performance amid real estate sector challenges
# Company: Signature Global
# Sector: Real Estate
# --------------------------------------------------
# Headline: Vedanta says it has arranged $250 million to settle Zambian copper mine debts
# Company: Vedanta
# Sector: Mining
# --------------------------------------------------
# Headline: Govt should review GST rates on vehicles powered by clean fuels: Rajiv Bajaj
# Company: Bajaj Auto
# Sector: Automotive
# --------------------------------------------------
# Headline: Adani Wilmar Q1 update: Company records robust volume growth at 13% YoY
# Company: Adani Wilmar
# Sector: Consumer Goods
# --------------------------------------------------
# Headline: DVC to invest Rs 20,000 crore in solar energy projects by 2030
# Company: DVC
# Sector: Energy
# --------------------------------------------------
# Headline: Bajaj Auto stock jumps after launch of world's first CNG-powered bike
# Company: Bajaj Auto
# Sector: Automotive
# --------------------------------------------------
# Headline: Coffee Day Enterprises' total default at Rs 433.91 crore in Q1 FY25
# Company: Coffee Day Enterprises
# Sector: Consumer Discretionary
# --------------------------------------------------
# Headline: Godrej Agrovet promoters to acquire 2.16% stake via block deal
# Company: Godrej Agrovet
# Sector: Agriculture
# --------------------------------------------------
# Headline: HDFC Bank said to mull loan portfolio sale amid growth scrutiny
# Company: HDFC Bank
# Sector: Financial Services
# --------------------------------------------------
# Headline: Thermax shares surge after subsidiary wins Rs 500-crore order in Botswana
# Company: Thermax
# Sector: Industrial Machinery
# --------------------------------------------------
# Headline: Kalyan Jewellers reports 27% revenue growth in Q1 FY'25, plans expansion
# Company: Kalyan Jewellers
# Sector: Consumer Discretionary (Luxury Goods/Jewelry)
# --------------------------------------------------
# Headline: Foxconn Chairman Young Liu to visit India this year
# Company: Foxconn
# Sector: Technology Hardware & Electronics Manufacturing
# Headline: Brigade Group to invest Rs 150 crore in third World Trade Center Tower at Infopark, Kochi
# Company: Brigade Group
# Sector: Real Estate
# --------------------------------------------------
# Headline: PNB Housing block deal: Asia Opportunities, General Atlantic to sell 4.2% stake for Rs 830 cr, says CNBC Awaaz
# Company: PNB Housing Finance
# Sector: Financial Services
# --------------------------------------------------
# Headline: India set for decade-high $2 billion bond inflows around JPMorgan index inclusion day
# Company: JPMorgan
# Sector: Financial Services
# --------------------------------------------------
# Headline: German auto component supplier ZF Group sells 7.5% stake in its Indian subsidiary
# Company: ZF Group
# Sector: Automotive
# --------------------------------------------------
# Headline: Coal India awards 23 dormant mines to private players
# Company: Coal India
# Sector: Energy
# --------------------------------------------------
# Headline: Indian automobile industry grows 19% to Rs 10.22 lakh crore in FY24: Report
# Company: None
# Sector: None
# --------------------------------------------------
# Headline: Jakson Green wins NTPC order for setting up project to produce 4G ethanol from flue gas
# Company: Jakson Green
# Sector: Energy
# --------------------------------------------------
# Headline: Salesforce launches public sector division in India; unveils Made-for-India digital lending solution
# Company: Salesforce
# Sector: Technology
# --------------------------------------------------
# Headline: Jio Financial Services appoints S Anantharaman as Group Chief Risk Officer
# Company: Jio Financial Services
# Sector: Financial Services
# --------------------------------------------------
# Headline: Adani Group to invest $100 billion in energy transition: Gautam Adani
# Company: Adani Group
# Sector: Energy
# --------------------------------------------------
# Headline: Govt not keen to go ahead with Concor disinvestment, says CNBC-Awaaz; stock down 2%
# Company: Concor
# Sector: Transportation
# --------------------------------------------------
# Headline: Air India to launch premium economy class on select domestic routes from July
# Company: Air India
# Sector: Aviation
# --------------------------------------------------
# Headline: HCLTech partners with Tecnotree to develop 5G-led GenAI solutions for telcos
# Company: HCLTech
# Sector: Information Technology Services
# --------------------------------------------------
# Headline: Should you place your bet on the Max Healthcare stock?
# Company: Max Healthcare
# Sector: Healthcare
# --------------------------------------------------
# Headline: Embraer sees India, Saudi Arabia, EU, US as strategic defense markets
# Company: Embraer
# Sector: Aerospace & Defense
# --------------------------------------------------
# Headline: ZEE names Mukund Galgali as acting CFO after Rohit Gupta steps down
# Company: ZEE
# Sector: Media and Entertainment
# --------------------------------------------------
# Headline: India largest market for Nestle's Maggi worldwide, 2nd biggest for KitKat
# Company: Nestle
# Sector: Consumer Goods
# --------------------------------------------------
# Headline: JSW MG Motor India partners with Tata Capital to offer financing solutions to dealers
# Company: JSW MG Motor India
# Sector: Automotive
# --------------------------------------------------
# Headline: Swati Maliwal writes to INDIA Bloc leaders, seeks time to discuss assault case
# Company: None
# Sector: None
# --------------------------------------------------
# Headline: HSBC sees $250 million of India swap deals before JPM inclusion
# Company: HSBC
# Sector: Financial Services
# --------------------------------------------------
# Headline: HUDCO raises $200 million from overseas lenders
# Company: HUDCO
# Sector: Financial Services
# --------------------------------------------------
# Headline: eBikeGo plans to expand e-two-wheeler fleet to 1 lakh units by FY26
# Company: eBikeGo
# Sector: Transportation
# --------------------------------------------------
# Headline: Vikram Solar bags order to supply 393.9 MWp solar modules
# Company: Vikram Solar
# Sector: Energy
# --------------------------------------------------
# Headline: Midhani shares rise on reports of talks with P&W to supply engine parts
# Company: Midhani
# Sector: Aerospace & Defense
# --------------------------------------------------
# Headline: Why should investors book profits in Go Digit and switch to ICICI Lombard?
# Company: ICICI Lombard
# Sector: Insurance
# --------------------------------------------------

# %%
len(companies), len(sectors)
# Out:
# (248, 248)

# %%
len(headlines)
# Out:
# 249

# %%
Why this leading auto component maker stays in the spotlight

# %%
dupl_companies = companies[:]
dupl_sectors = sectors[:]

# %%
headlines.index('Why this leading auto component maker stays in the spotlight')
# Out:
# 52

# %%
a = [1,2,3]

# %%
a.insert(1, 'a')

# %%
a
# Out:
# [1, 'a', 2, 3]

# %%
companies.insert(52, 'None')
sectors.insert(52, 'None')

# %%
len(companies)
# Out:
# 249

# %%
df['Company'] = companies
df['Sector'] = sectors

# %%
df.head()
# Out:
#                                            Headlines  \
# 0  Coal India revises e-auction norms: Is there m...
# 1    D-Mart: Margin miss in Q1; valuations expensive
# 2  TCS chief cautious of economic slowdown, but r...
# 3  SBI raises lending rates by 5-10 bps across mo...
# 4  Investors of TCS, HCL should tally their optim...
#
#                                              Article  Interest     Company  \
# 0  Highlights  Coal India announces plans to ease...         1  Coal India
# 1  Highlights  Healthy revenue growth, but margin...         1      D-Mart
# 2  Tata Consultancy Services Ltd (TCS) stays caut...         1         TCS
# 3  State Bank of India (SBI) has raised its bench...         1         SBI
# 4  Shares of Tata Consultancy Services (TCS) and ...         0         TCS
#
#                    Sector
# 0                  Energy
# 1                  Retail
# 2  Information Technology
# 3                 Banking
# 4  Information Technology

# %%
df.columns
# Out:
# Index(['Headlines', 'Article', 'Interest', 'Company', 'Sector'], dtype='object')

# %%
df = df.reindex(columns=['Headlines', 'Article', 'Company', 'Sector', 'Interest',])

# %%
df.head()
# Out:
#                                            Headlines  \
# 0  Coal India revises e-auction norms: Is there m...
# 1    D-Mart: Margin miss in Q1; valuations expensive
# 2  TCS chief cautious of economic slowdown, but r...
# 3  SBI raises lending rates by 5-10 bps across mo...
# 4  Investors of TCS, HCL should tally their optim...
#
#                                              Article     Company  \
# 0  Highlights  Coal India announces plans to ease...  Coal India
# 1  Highlights  Healthy revenue growth, but margin...      D-Mart
# 2  Tata Consultancy Services Ltd (TCS) stays caut...         TCS
# 3  State Bank of India (SBI) has raised its bench...         SBI
# 4  Shares of Tata Consultancy Services (TCS) and ...         TCS
#
#                    Sector  Interest
# 0                  Energy         1
# 1                  Retail         1
# 2  Information Technology         1
# 3                 Banking         1
# 4  Information Technology         0

# %%
df.to_csv('training_binary_class.csv', index=False)

# %%
df
# Out:
#                                              Headlines  \
# 0    Coal India revises e-auction norms: Is there m...
# 1      D-Mart: Margin miss in Q1; valuations expensive
# 2    TCS chief cautious of economic slowdown, but r...
# 3    SBI raises lending rates by 5-10 bps across mo...
# 4    Investors of TCS, HCL should tally their optim...
# ..                                                 ...
# 244    HUDCO raises $200 million from overseas lenders
# 245  eBikeGo plans to expand e-two-wheeler fleet to...
# 246  Vikram Solar bags order to supply 393.9 MWp so...
# 247  Midhani shares rise on reports of talks with P...
# 248  Why should investors book profits in Go Digit ...
#
#                                                Article        Company  \
# 0    Highlights  Coal India announces plans to ease...     Coal India
# 1    Highlights  Healthy revenue growth, but margin...         D-Mart
# 2    Tata Consultancy Services Ltd (TCS) stays caut...            TCS
# 3    State Bank of India (SBI) has raised its bench...            SBI
# 4    Shares of Tata Consultancy Services (TCS) and ...            TCS
# ..                                                 ...            ...
# 244  Housing and Urban Development Corporation (HUD...          HUDCO
# 245  Electric vehicle rental services operator eBik...        eBikeGo
# 246  Solar energy solutions provider Vikram Solar o...   Vikram Solar
# 247  Mishra Dhatu Nigam Limited (Midhani) reportedl...        Midhani
# 248  Highlights  Go Digit reported strong earnings ...  ICICI Lombard
#
#                      Sector  Interest
# 0                    Energy         1
# 1                    Retail         1
# 2    Information Technology         1
# 3                   Banking         1
# 4    Information Technology         0
# ..                      ...       ...
# 244      Financial Services         1
# 245          Transportation         0
# 246                  Energy         1
# 247     Aerospace & Defense         1
# 248               Insurance         0
#
# [249 rows x 5 columns]

# %%
# !ls Datasets
# Out:
# headlines+articles.csv	test.csv   training_binary_class.csv
# test2.csv		train.csv

# %%
data = pd.read_csv('Datasets/test2.csv')

# %%
headlines = list(data['Headlines'])

# %%
data.shape, len(headlines)
# Out:
# ((54, 2), 54)

# %%
import anthropic
import time
from tenacity import retry, wait_exponential, stop_after_attempt

# %%
client = anthropic.Anthropic(api_key=#Your key here)

# Retry decorator
@retry(wait=wait_exponential(multiplier=1, min=4, max=10), stop=stop_after_attempt(5))
def make_api_call(headline):
    return client.messages.create(
        model="claude-3-5-sonnet-20240620",
        max_tokens=1000,
        temperature=0,
        system="You are an expert in identifying companies and their sectors from news headlines. Respond with the company name followed by a comma and then the sector.If you are unable to find a company, just put None in both company and sector.Also if there are more than one company, just answer with the first one",
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "text",
                        "text": f"Identify the company and its sector from this headline: {headline}"
                    }
                ]
            }
        ]
    )

# List of headlines

# Lists to store companies and sectors
companies = []
sectors = []

# Loop through each headline
for headline in headlines:
    try:
        message = make_api_call(headline)
        
        # Extract the text content from the message
        response = message.content[0].text if isinstance(message.content, list) else message.content.text
        
        # Now we can safely use strip() and split()
        response = response.strip()
        company, sector = response.split(',')
        
        # Append to the respective lists
        companies.append(company.strip())
        sectors.append(sector.strip())
        
        # Print the result
        print(f"Headline: {headline}")
        print(f"Company: {company.strip()}")
        print(f"Sector: {sector.strip()}")
        print("-" * 50)
        
        # Add a delay between requests
        time.sleep(1)
    except Exception as e:
        print(f"Error processing headline: {headline}")
        print(f"Error: {str(e)}")
# Out:
# Headline: Indian Hotels Company: Temporary blip in Q1 FY25; long-term story intact
# Company: Indian Hotels Company
# Sector: Hospitality
# --------------------------------------------------
# Headline: Kotak Mahindra Bank Q1 FY25 – under the shadow of the embargo
# Company: Kotak Mahindra Bank
# Sector: Financial Services
# --------------------------------------------------
# Headline: Byju’s was the problem, not edtech
# Company: Byju's
# Sector: Education Technology (EdTech)
# --------------------------------------------------
# Headline: HDFC Bank Q1 FY25 – no major improvement, loan growth to lag deposit curve in near term
# Company: HDFC Bank
# Sector: Banking
# --------------------------------------------------
# Headline: Morning Scan: All the big stories to get you started for the day
# Company: None
# Sector: None
# --------------------------------------------------
# Headline: Telecom tower companies want Budget to extend input tax credit to infra
# Company: None
# Sector: None
# --------------------------------------------------
# Headline: CLSA finds markets vulnerable going into Budget as expectations rise
# Company: None
# Sector: None
# --------------------------------------------------
# Headline
# Company: None
# Sector: None
# --------------------------------------------------
# Headline: Budget 2024 Date
# Company: None
# Sector: None
# --------------------------------------------------
# Headline: Union Budget 2024
# Company: None
# Sector: None
# --------------------------------------------------
# Headline: What Asian Paints' results say about its tryst with competition
# Company: Asian Paints
# Sector: Consumer Goods (Paints and Coatings)
# --------------------------------------------------
# Headline: Wipro Holdings UK transfers entire stake in Wipro Financial Outsourcing to Wipro IT Services UK
# Company: Wipro
# Sector: Information Technology Services
# --------------------------------------------------
# Headline: What can Union Budget 2024 do to sustain the dream run in infrastructure sector?
# Company: None
# Sector: None
# --------------------------------------------------
# Headline: LTI Mindtree Q1 FY25 – strong quarter, encouraging outlook
# Company: LTI Mindtree
# Sector: Information Technology Services
# --------------------------------------------------
# Headline: Air India rolls out VRS for non-flying staff ahead of Vistara merger
# Company: Air India
# Sector: Aviation
# --------------------------------------------------
# Headline: How Tata Power’s improved balance sheet is fuelling its capex
# Company: Tata Power
# Sector: Utilities
# --------------------------------------------------
# Headline: DLF to expand housing, commercial property business; entering Mumbai, Goa: Chairman Rajiv Singh
# Company: DLF
# Sector: Real Estate
# --------------------------------------------------
# Headline: Dharana Capital invests Rs 400 crore in on-demand home service provider Urban Company
# Company: Urban Company
# Sector: Consumer Services
# --------------------------------------------------
# Headline: Sanofi to invest Euro 400 million in its  Hyderabad GCC by 2030
# Company: Sanofi
# Sector: Healthcare
# --------------------------------------------------
# Headline: Bajaj Electricals' MD & CEO Anuj Poddar steps down
# Company: Bajaj Electricals
# Sector: Consumer Electronics
# --------------------------------------------------
# Headline: Panasonic Avionics opens new software design facility in Pune
# Company: Panasonic Avionics
# Sector: Electronics Manufacturing
# --------------------------------------------------
# Headline: Pratt & Whitney opens new customer service centre in Bengaluru
# Company: Pratt & Whitney
# Sector: Aerospace
# --------------------------------------------------
# Headline: Glenmark Pharma gets USFDA nod for seizure treatment drug
# Company: Glenmark Pharma
# Sector: Healthcare
# --------------------------------------------------
# Headline: Expect domestic two-wheeler sales to reach peak levels of FY19 latest by Q1 FY26: Bajaj Auto
# Company: Bajaj Auto
# Sector: Automotive
# --------------------------------------------------
# Headline: Tata Power to invest Rs 20,000 crore capex in FY25: N Chandrasekaran
# Company: Tata Power
# Sector: Utilities
# --------------------------------------------------
# Headline: Network18 Q1FY25: TV news revenue jumps 14%, digital news business records 34% growth
# Company: Network18
# Sector: Media
# --------------------------------------------------
# Headline: Home delivery of liquor through Swiggy, Zomato, BigBasket likely soon in more states: Report
# Company: Swiggy
# Sector: Consumer Services
# --------------------------------------------------
# Headline: Adani-IHC JV acquires cloud platform company Coredge.io from Parserlabs
# Company: Adani
# Sector: Conglomerate
# --------------------------------------------------
# Headline: HDFC Life Q1 FY25: Healthy growth, encouraging guidance
# Company: HDFC Life
# Sector: Insurance
# --------------------------------------------------

# %%
data['Companies'] = companies
data['Sectors'] = sectors

# %%
interest = []

for i in headlines:
    print(i)
    ans = input('Intrested or not: ')
    interest.append(ans)
# Out:
# Indian Hotels Company: Temporary blip in Q1 FY25; long-term story intact
# Intrested or not: 1
# Kotak Mahindra Bank Q1 FY25 – under the shadow of the embargo
# Intrested or not: 1
# Byju’s was the problem, not edtech
# Intrested or not: 0
# HDFC Bank Q1 FY25 – no major improvement, loan growth to lag deposit curve in near term
# Intrested or not: 0
# Morning Scan: All the big stories to get you started for the day
# Intrested or not: 0
# Telecom tower companies want Budget to extend input tax credit to infra
# Intrested or not: 1
# CLSA finds markets vulnerable going into Budget as expectations rise
# Intrested or not: 0
# ITR filing 2024: How tax harvesting can slash the tax payable, boost returns
# Intrested or not: 0
# Byju's founder faces reckoning as startup implodes
# Intrested or not: 0
# Wipro Q1 FY25: Growth remains elusive
# Intrested or not: 1
# Suzuki sees India’s automobile market growing fivefold by 2047
# Intrested or not: 1
# Vedanta wins bids for Nickel, Chromium, and PGE blocks in Karnataka and Bihar
# Intrested or not: 1
# Air India issues apology to passengers of Delhi-San Francisco flight, offers full fare refund
# Intrested or not: 0
# Reliance Industries Q1: Positive results, favourable outlook
# Intrested or not: 1
# Tariff hikes will strengthen the telecom sector in the long term: Jio Platform's Anshuman Thakur
# Intrested or not: 1
# UltraTech Cement's expansion, efficiency boosts to help lower costs by Rs 300 per tonne
# Intrested or not: 1
# UltraTech's 23% stake in India Cements seen as promising market investment: CFO Atul Daga
# Intrested or not: 1
# HDFC Bank CSR spend crosses Rs 945 crore in FY24
# Intrested or not: 0
# KPI Green Energy gets new 100 MW hybrid project
# Intrested or not: 1
# Zydus Lifesciences gets USFDA nod for diabetes drug
# Intrested or not: 1
# Air India to operate relief flight from Mumbai to fly passengers stranded in Russia
# Intrested or not: 0
# Ramkrishna Titagarh Rail nearing financial closure for Rs 2,180 crore forged wheels project
# Intrested or not: 1
# SpiceJet board to consider raising fresh capital via QIP on July 23
# Intrested or not: 1
# Vedanta Resources pays $246 million dues to help revive operations at Zambian copper mine
# Intrested or not: 1
# Sanstar IPO: Does this maize-based ingredients play make a worthy investment?
# Intrested or not: 0
# Infosys Q1 FY25 – Does all-round strength make the stock worthy of fresh allocation?
# Intrested or not: 1
# Citigroup sees India luring $100 billion in foreign investment
# Intrested or not: 1
# Bank of India raises Rs 5,000 crore via long-term infrastructure bonds
# Intrested or not: 1
# L&T Tech Q1 net profit up 1% YoY at Rs 314 crore
# Intrested or not: 1
# Tata Technologies Q1 results: Net profit down 15% at Rs 162.03 crore
# Intrested or not: 1
# Government grants three-month extension to R P Goyal as NHPC CMD
# Intrested or not: 0
# Tata Power Renewable Energy, NHPC Renewable join hands for installation of rooftop solar projects
# Intrested or not: 1
# Demand for creation of new NBFC-PSL category in Budget to boost MSME sector
# Intrested or not: 0
# Budget 2024 Date
# Intrested or not: 0
# Union Budget 2024
# Intrested or not: 0
# What Asian Paints' results say about its tryst with competition
# Intrested or not: 0
# Wipro Holdings UK transfers entire stake in Wipro Financial Outsourcing to Wipro IT Services UK
# Intrested or not: 0
# What can Union Budget 2024 do to sustain the dream run in infrastructure sector?
# Intrested or not: 0
# LTI Mindtree Q1 FY25 – strong quarter, encouraging outlook
# Intrested or not: 1
# Air India rolls out VRS for non-flying staff ahead of Vistara merger
# Intrested or not: 0
# How Tata Power’s improved balance sheet is fuelling its capex
# Intrested or not: 1
# DLF to expand housing, commercial property business; entering Mumbai, Goa: Chairman Rajiv Singh
# Intrested or not: 1
# Dharana Capital invests Rs 400 crore in on-demand home service provider Urban Company
# Intrested or not: 1
# Sanofi to invest Euro 400 million in its  Hyderabad GCC by 2030
# Intrested or not: 1
# Bajaj Electricals' MD & CEO Anuj Poddar steps down
# Intrested or not: 0
# Panasonic Avionics opens new software design facility in Pune
# Intrested or not: 0
# Pratt & Whitney opens new customer service centre in Bengaluru
# Intrested or not: 0
# Glenmark Pharma gets USFDA nod for seizure treatment drug
# Intrested or not: 0
# Expect domestic two-wheeler sales to reach peak levels of FY19 latest by Q1 FY26: Bajaj Auto
# Intrested or not: 0
# Tata Power to invest Rs 20,000 crore capex in FY25: N Chandrasekaran
# Intrested or not: 1
# Network18 Q1FY25: TV news revenue jumps 14%, digital news business records 34% growth
# Intrested or not: 1
# Home delivery of liquor through Swiggy, Zomato, BigBasket likely soon in more states: Report
# Intrested or not: 0
# Adani-IHC JV acquires cloud platform company Coredge.io from Parserlabs
# Intrested or not: 1
# HDFC Life Q1 FY25: Healthy growth, encouraging guidance
# Intrested or not: 1

# %%
data['Interest'] = interest

# %%
data.head()
# Out:
#                                            Headlines  \
# 0  Indian Hotels Company: Temporary blip in Q1 FY...
# 1  Kotak Mahindra Bank Q1 FY25 – under the shadow...
# 2                 Byju’s was the problem, not edtech
# 3  HDFC Bank Q1 FY25 – no major improvement, loan...
# 4  Morning Scan: All the big stories to get you s...
#
#                                              Article Interest  \
# 0  Highlights  Growth slows in Q1FY25 Strong dema...        1
# 1  Highlights  Weak internals partly due to the R...        1
# 2  Following Byju’s fall from being India’s most ...        0
# 3  Highlights  Headline business growth numbers i...        0
# 4  #1. Amazon sounds out IPO-bound Swiggy to buy ...        0
#
#                Companies                        Sectors
# 0  Indian Hotels Company                    Hospitality
# 1    Kotak Mahindra Bank             Financial Services
# 2                 Byju's  Education Technology (EdTech)
# 3              HDFC Bank                        Banking
# 4                   None                           None

# %%
data = data.reindex(columns=['Headlines', 'Article', 'Companies', 'Sectors', 'Interest',])

# %%
data.head()
# Out:
#                                            Headlines  \
# 0  Indian Hotels Company: Temporary blip in Q1 FY...
# 1  Kotak Mahindra Bank Q1 FY25 – under the shadow...
# 2                 Byju’s was the problem, not edtech
# 3  HDFC Bank Q1 FY25 – no major improvement, loan...
# 4  Morning Scan: All the big stories to get you s...
#
#                                              Article              Companies  \
# 0  Highlights  Growth slows in Q1FY25 Strong dema...  Indian Hotels Company
# 1  Highlights  Weak internals partly due to the R...    Kotak Mahindra Bank
# 2  Following Byju’s fall from being India’s most ...                 Byju's
# 3  Highlights  Headline business growth numbers i...              HDFC Bank
# 4  #1. Amazon sounds out IPO-bound Swiggy to buy ...                   None
#
#                          Sectors Interest
# 0                    Hospitality        1
# 1             Financial Services        1
# 2  Education Technology (EdTech)        0
# 3                        Banking        0
# 4                           None        0

# %%
data.to_csv('Datasets/test2_complete.csv', index=False)
